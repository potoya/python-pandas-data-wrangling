# %%
import pandas as pd

# %%
df = pd.read_csv('EU-Popular-Cities-Prices - PreProcesed.csv', sep=',')
df
# Out:
#       Unnamed: 0  city_id            city_name  item_id  \
# 0              0     6379  Zurich, Switzerland        1
# 1              1     6379  Zurich, Switzerland        2
# 2              2     6379  Zurich, Switzerland        3
# 3              3     6379  Zurich, Switzerland        4
# 4              4     6379  Zurich, Switzerland        5
# 5              5     6379  Zurich, Switzerland        6
# 6              6     6379  Zurich, Switzerland        7
# 7              7     6379  Zurich, Switzerland        8
# 8              8     6379  Zurich, Switzerland        9
# 9              9     6379  Zurich, Switzerland       11
# 10            10     6379  Zurich, Switzerland       12
# 11            11     6379  Zurich, Switzerland       13
# 12            12     6379  Zurich, Switzerland       14
# 13            13     6379  Zurich, Switzerland       15
# 14            14     6379  Zurich, Switzerland       16
# 15            15     6379  Zurich, Switzerland       17
# 16            16     6379  Zurich, Switzerland       18
# 17            17     6379  Zurich, Switzerland       19
# 18            18     6379  Zurich, Switzerland       20
# 19            19     6379  Zurich, Switzerland       24
# 20            20     6379  Zurich, Switzerland       25
# 21            21     6379  Zurich, Switzerland       26
# 22            22     6379  Zurich, Switzerland       27
# 23            23     6379  Zurich, Switzerland       28
# 24            24     6379  Zurich, Switzerland       29
# 25            25     6379  Zurich, Switzerland       30
# 26            26     6379  Zurich, Switzerland       32
# 27            27     6379  Zurich, Switzerland       33
# 28            28     6379  Zurich, Switzerland       40
# 29            29     6379  Zurich, Switzerland       42
# ...          ...      ...                  ...      ...
# 1785          25     6029     Lisbon, Portugal       30
# 1786          26     6029     Lisbon, Portugal       32
# 1787          27     6029     Lisbon, Portugal       33
# 1788          28     6029     Lisbon, Portugal       40
# 1789          29     6029     Lisbon, Portugal       42
# 1790          30     6029     Lisbon, Portugal       44
# 1791          31     6029     Lisbon, Portugal       60
# 1792          32     6029     Lisbon, Portugal       62
# 1793          33     6029     Lisbon, Portugal       64
# 1794          34     6029     Lisbon, Portugal       66
# 1795          35     6029     Lisbon, Portugal      206
# 1796          36     6029     Lisbon, Portugal      224
# 1797          37     6029     Lisbon, Portugal      100
# 1798          38     6029     Lisbon, Portugal      228
# 1799          39     6029     Lisbon, Portugal      101
# 1800          40     6029     Lisbon, Portugal      105
# 1801          41     6029     Lisbon, Portugal      106
# 1802          42     6029     Lisbon, Portugal      107
# 1803          43     6029     Lisbon, Portugal      108
# 1804          44     6029     Lisbon, Portugal      109
# 1805          45     6029     Lisbon, Portugal      110
# 1806          46     6029     Lisbon, Portugal      111
# 1807          47     6029     Lisbon, Portugal      112
# 1808          48     6029     Lisbon, Portugal      113
# 1809          49     6029     Lisbon, Portugal      114
# 1810          50     6029     Lisbon, Portugal      115
# 1811          51     6029     Lisbon, Portugal      116
# 1812          52     6029     Lisbon, Portugal      118
# 1813          53     6029     Lisbon, Portugal      119
# 1814          54     6029     Lisbon, Portugal      121
#
#                                               item_name  lowest_price  \
# 0             Meal, Inexpensive Restaurant, Restaurants     20.000000
# 1     Meal for 2 People, Mid-range Restaurant, Three...     70.000000
# 2     McMeal at McDonalds (or Equivalent Combo Meal)...     12.000000
# 3        Domestic Beer (0.5 liter draught), Restaurants      5.000000
# 4        Imported Beer (0.33 liter bottle), Restaurants      5.000000
# 5           Coke/Pepsi (0.33 liter bottle), Restaurants      3.000000
# 6               Water (0.33 liter bottle) , Restaurants      2.500000
# 7                    Milk (regular), (1 liter), Markets      1.500000
# 8             Loaf of Fresh White Bread (500g), Markets      2.000000
# 9                          Eggs (regular) (12), Markets      4.000000
# 10                          Local Cheese (1kg), Markets     16.000000
# 11                    Water (1.5 liter bottle), Markets      0.900000
# 12                  Bottle of Wine (Mid-Range), Markets     10.000000
# 13            Domestic Beer (0.5 liter bottle), Markets      1.500000
# 14           Imported Beer (0.33 liter bottle), Markets      1.890000
# 15               Cigarettes 20 Pack (Marlboro), Markets      8.000000
# 16     One-way Ticket (Local Transport), Transportation      3.000000
# 17    Chicken Breasts (Boneless, Skinless), (1kg), M...     16.000000
# 18         Monthly Pass (Regular Price), Transportation     65.166667
# 19                   Gasoline (1 liter), Transportation      1.520000
# 20    Volkswagen Golf 1.4 90 KW Trendline (Or Equiva...  20000.000000
# 21    Apartment (1 bedroom) in City Centre, Rent Per...   1200.000000
# 22    Apartment (1 bedroom) Outside of Centre, Rent ...   1000.000000
# 23    Apartment (3 bedrooms) in City Centre, Rent Pe...   2400.000000
# 24    Apartment (3 bedrooms) Outside of Centre, Rent...   1800.000000
# 25    Basic (Electricity, Heating, Cooling, Water, G...     85.000000
# 26    1 min. of Prepaid Mobile Tariff Local (No Disc...      0.130000
# 27    Internet (60 Mbps or More, Unlimited Data, Cab...     40.000000
# 28    Fitness Club, Monthly Fee for 1 Adult, Sports ...     58.333333
# 29    Tennis Court Rent (1 Hour on Weekend), Sports ...     28.000000
# ...                                                 ...           ...
# 1785  Basic (Electricity, Heating, Cooling, Water, G...     60.000000
# 1786  1 min. of Prepaid Mobile Tariff Local (No Disc...      0.080000
# 1787  Internet (60 Mbps or More, Unlimited Data, Cab...     25.000000
# 1788  Fitness Club, Monthly Fee for 1 Adult, Sports ...     29.000000
# 1789  Tennis Court Rent (1 Hour on Weekend), Sports ...      8.000000
# 1790  Cinema, International Release, 1 Seat, Sports ...      6.000000
# 1791  1 Pair of Jeans (Levis 501 Or Similar), Clothi...     50.000000
# 1792  1 Summer Dress in a Chain Store (Zara, H&M, .....     20.000000
# 1793  1 Pair of Nike Running Shoes (Mid-Range), Clot...     60.000000
# 1794  1 Pair of Men Leather Business Shoes, Clothing...     57.000000
# 1795  Toyota Corolla 1.6l 97kW Comfort (Or Equivalen...  20000.000000
# 1796  Preschool (or Kindergarten), Full Day, Private...    300.000000
# 1797  Price per Square Meter to Buy Apartment in Cit...   3000.000000
# 1798  International Primary School, Yearly for 1 Chi...   5400.000000
# 1799  Price per Square Meter to Buy Apartment Outsid...   1500.000000
# 1800  Average Monthly Net Salary (After Tax), Salari...    700.000000
# 1801  Mortgage Interest Rate in Percentages (%), Yea...      2.000000
# 1802         Taxi Start (Normal Tariff), Transportation      3.000000
# 1803           Taxi 1km (Normal Tariff), Transportation      0.470000
# 1804  Taxi 1hour Waiting (Normal Tariff), Transporta...     14.800000
# 1805                              Apples (1kg), Markets      1.200000
# 1806                             Oranges (1kg), Markets      0.900000
# 1807                              Potato (1kg), Markets      0.650000
# 1808                          Lettuce (1 head), Markets      0.500000
# 1809                  Cappuccino (regular), Restaurants      0.800000
# 1810                       Rice (white), (1kg), Markets      0.750000
# 1811                              Tomato (1kg), Markets      1.000000
# 1812                              Banana (1kg), Markets      1.000000
# 1813                               Onion (1kg), Markets      0.700000
# 1814  Beef Round (1kg) (or Equivalent Back Leg Red M...      8.000000
#
#       highest_price  average_price currency  contributors  data_points  toEur
# 0         30.000000      25.000000      CHF           321           37   0.88
# 1        120.000000     100.000000      CHF           321           37   0.88
# 2         17.000000      14.000000      CHF           321           28   0.88
# 3          8.000000       7.000000      CHF           321           31   0.88
# 4          8.000000       6.000000      CHF           321           29   0.88
# 5          5.000000       4.053571      CHF           321           28   0.88
# 6          5.000000       3.634615      CHF           321           26   0.88
# 7          2.000000       1.742500      CHF           321           20   0.88
# 8          4.000000       2.704545      CHF           321           22   0.88
# 9          8.000000       5.336522      CHF           321           23   0.88
# 10        40.000000      25.165714      CHF           321           21   0.88
# 11         2.000000       1.241667      CHF           321           24   0.88
# 12        18.000000      12.000000      CHF           321           20   0.88
# 13         3.000000       1.963043      CHF           321           23   0.88
# 14         4.000000       2.651667      CHF           321           18   0.88
# 15         8.800000       8.000000      CHF           321           23   0.88
# 16         4.400000       4.000000      CHF           321           59   0.88
# 17        34.000000      25.850000      CHF           321           20   0.88
# 18        95.000000      85.000000      CHF           321           56   0.88
# 19         1.800000       1.661282      CHF           321           39   0.88
# 20     26000.000000   22650.000000      CHF           321           14   0.88
# 21      2400.000000    1749.062500      CHF           321           48   0.88
# 22      1800.000000    1340.285714      CHF           321           42   0.88
# 23      4500.000000    3184.883721      CHF           321           43   0.88
# 24      3500.000000    2433.333333      CHF           321           45   0.88
# 25       300.000000     174.269965      CHF           321           24   0.88
# 26         0.500000       0.260000      CHF           321           22   0.88
# 27        80.000000      58.523684      CHF           321           38   0.88
# 28       116.666667      80.886525      CHF           321           47   0.88
# 29        55.000000      37.500000      CHF           321           20   0.88
# ...             ...            ...      ...           ...          ...    ...
# 1785     145.714286      94.464399      EUR           494           57   1.00
# 1786       0.300000       0.192800      EUR           494           25   1.00
# 1787      40.000000      31.716508      EUR           494           63   1.00
# 1788      50.000000      35.274359      EUR           494           78   1.00
# 1789      20.000000      11.500000      EUR           494           20   1.00
# 1790       7.500000       7.000000      EUR           494           81   1.00
# 1791     100.000000      81.417910      EUR           494           67   1.00
# 1792      40.000000      28.134394      EUR           494           66   1.00
# 1793     100.000000      72.852941      EUR           494           68   1.00
# 1794     120.000000      81.767857      EUR           494           56   1.00
# 1795   27000.000000   23252.200000      EUR           494           20   1.00
# 1796     500.000000     413.714286      EUR           494           35   1.00
# 1797    6000.000000    4053.258065      EUR           494           31   1.00
# 1798   14400.000001    7852.173913      EUR           494           23   1.00
# 1799    2888.000000    2051.221046      EUR           494           28   1.00
# 1800    1200.000000     871.842188      EUR           494           64   1.00
# 1801       3.250000       2.472609      EUR           494           23   1.00
# 1802       3.900000       3.250000      EUR           494           68   1.00
# 1803       0.800000       0.470000      EUR           494           21   1.00
# 1804      15.000000      14.800000      EUR           494           18   1.00
# 1805       2.300000       1.646087      EUR           494           23   1.00
# 1806       2.000000       1.266087      EUR           494           23   1.00
# 1807       2.000000       1.000833      EUR           494           24   1.00
# 1808       1.500000       0.942083      EUR           494           24   1.00
# 1809       2.500000       1.496441      EUR           494           59   1.00
# 1810       1.500000       0.968519      EUR           494           27   1.00
# 1811       2.000000       1.554000      EUR           494           25   1.00
# 1812       2.000000       1.224167      EUR           494           24   1.00
# 1813       2.000000       0.993000      EUR           494           20   1.00
# 1814      12.000000       9.285238      EUR           494           21   1.00
#
# [1815 rows x 12 columns]

# %%
# Filter price items to include in basic costs

filter = df.item_id.isin([1,4,40,44,8,9,10,11,12,13,19,110,111,112,113,115,116,118,119,121,120,20,30,33,27,105])
df_filtered = df[filter]

# %%
# Dictionaries for conversion and bining purposes

toMonthlyCostDict = {1:4, 4:4, 40:1, 44:1, 8:4, 9:4, 10:4, 11:4, 12:4, 13:4, 19:4, 110:4, 111:4, 112:4, 113:4, 115:4, 116:4, 118:4, 
                      119:4, 121:4, 20:1, 30:1, 33:1, 27:1, 105:1}
itemType = {1:'HOBBIES', 4:'HOBBIES', 40:'HOBBIES', 44:'HOBBIES', 8:'MARKET', 9:'MARKET', 10:'MARKET', 11:'MARKET', 12:'MARKET',
                13:'MARKET', 19:'MARKET', 110:'MARKET', 111:'MARKET', 112:'MARKET', 113:'MARKET', 115:'MARKET', 116:'MARKET', 
                118:'MARKET', 119:'MARKET', 121:'MARKET', 20:'TRANSPORT', 30:'UTILITIES', 33:'UTILITIES', 27:'RENT', 105:'SALARY'}

# %%
# Appending new columns to dataframe
a = []
b = []
for itemId in df_filtered.item_id:
    a.append(toMonthlyCostDict[itemId])
    b.append(itemType[itemId])
df_filtered['toMonthlyCost'] = a
df_filtered['item_type'] = b
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_filtered.head()
# Out:
#    Unnamed: 0  city_id            city_name  item_id  \
# 0           0     6379  Zurich, Switzerland        1
# 3           3     6379  Zurich, Switzerland        4
# 7           7     6379  Zurich, Switzerland        8
# 8           8     6379  Zurich, Switzerland        9
# 9           9     6379  Zurich, Switzerland       11
#
#                                         item_name  lowest_price  \
# 0       Meal, Inexpensive Restaurant, Restaurants          20.0
# 3  Domestic Beer (0.5 liter draught), Restaurants           5.0
# 7              Milk (regular), (1 liter), Markets           1.5
# 8       Loaf of Fresh White Bread (500g), Markets           2.0
# 9                    Eggs (regular) (12), Markets           4.0
#
#    highest_price  average_price currency  contributors  data_points  toEur  \
# 0           30.0      25.000000      CHF           321           37   0.88
# 3            8.0       7.000000      CHF           321           31   0.88
# 7            2.0       1.742500      CHF           321           20   0.88
# 8            4.0       2.704545      CHF           321           22   0.88
# 9            8.0       5.336522      CHF           321           23   0.88
#
#    toMonthlyCost item_type
# 0              4   HOBBIES
# 3              4   HOBBIES
# 7              4    MARKET
# 8              4    MARKET
# 9              4    MARKET

# %%
# Calculating monthly prices for each iterm

df_filtered['avg_monthly_cost'] = df_filtered.average_price * df_filtered.toEur * df_filtered.toMonthlyCost 
data = df_filtered[['city_id', 'city_name', 'item_id', 'item_name', 'item_type', 'avg_monthly_cost']]
data.head()
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    city_id            city_name  item_id  \
# 0     6379  Zurich, Switzerland        1
# 3     6379  Zurich, Switzerland        4
# 7     6379  Zurich, Switzerland        8
# 8     6379  Zurich, Switzerland        9
# 9     6379  Zurich, Switzerland       11
#
#                                         item_name item_type  avg_monthly_cost
# 0       Meal, Inexpensive Restaurant, Restaurants   HOBBIES         88.000000
# 3  Domestic Beer (0.5 liter draught), Restaurants   HOBBIES         24.640000
# 7              Milk (regular), (1 liter), Markets    MARKET          6.133600
# 8       Loaf of Fresh White Bread (500g), Markets    MARKET          9.520000
# 9                    Eggs (regular) (12), Markets    MARKET         18.784557

# %%
# Aggregating items by category 

data = data.groupby(['city_name', 'item_type']).sum()
data[:20]
# Out:
#                                   city_id  item_id  avg_monthly_cost
# city_name              item_type
# Amsterdam, Netherlands HOBBIES      23724       89        127.158333
#                        MARKET       88965     1107        225.592814
#                        RENT          5931       27       1143.055556
#                        SALARY        5931      105       2492.607843
#                        TRANSPORT     5931       20         93.000000
#                        UTILITIES    11862       63        195.730508
# Barcelona, Spain       HOBBIES      25184       89        110.010714
#                        MARKET       94440     1107        168.478419
#                        RENT          6296       27        726.666667
#                        SALARY        6296      105       1330.619032
#                        TRANSPORT     6296       20         50.000000
#                        UTILITIES    12592       63        182.035825
# Basel, Switzerland     HOBBIES      25392       89        214.328889
#                        MARKET       95220     1107        507.185067
#                        RENT          6348       27       1012.000000
#                        SALARY        6348      105       4646.279906
#                        TRANSPORT     6348       20         70.400000
#                        UTILITIES    12696       63        273.857988
# Berlin, Germany        HOBBIES      21756       89         82.107692
#                        MARKET       81585     1107        188.188574

# %%
# Aggregation Output -> using rest_index() to undo groupBy binding on (city_name, item_type)
data = data.reset_index()[['city_name','item_type','avg_monthly_cost']]
data
# Out:
#                   city_name  item_type  avg_monthly_cost
# 0    Amsterdam, Netherlands    HOBBIES        127.158333
# 1    Amsterdam, Netherlands     MARKET        225.592814
# 2    Amsterdam, Netherlands       RENT       1143.055556
# 3    Amsterdam, Netherlands     SALARY       2492.607843
# 4    Amsterdam, Netherlands  TRANSPORT         93.000000
# 5    Amsterdam, Netherlands  UTILITIES        195.730508
# 6          Barcelona, Spain    HOBBIES        110.010714
# 7          Barcelona, Spain     MARKET        168.478419
# 8          Barcelona, Spain       RENT        726.666667
# 9          Barcelona, Spain     SALARY       1330.619032
# 10         Barcelona, Spain  TRANSPORT         50.000000
# 11         Barcelona, Spain  UTILITIES        182.035825
# 12       Basel, Switzerland    HOBBIES        214.328889
# 13       Basel, Switzerland     MARKET        507.185067
# 14       Basel, Switzerland       RENT       1012.000000
# 15       Basel, Switzerland     SALARY       4646.279906
# 16       Basel, Switzerland  TRANSPORT         70.400000
# 17       Basel, Switzerland  UTILITIES        273.857988
# 18          Berlin, Germany    HOBBIES         82.107692
# 19          Berlin, Germany     MARKET        188.188574
# 20          Berlin, Germany       RENT        653.871212
# 21          Berlin, Germany     SALARY       2157.578704
# 22          Berlin, Germany  TRANSPORT         81.000000
# 23          Berlin, Germany  UTILITIES        275.349939
# 24        Bern, Switzerland    HOBBIES        169.194667
# 25        Bern, Switzerland     MARKET        468.054400
# 26        Bern, Switzerland       RENT        753.866667
# 27        Bern, Switzerland     SALARY       4593.162282
# 28        Bern, Switzerland  TRANSPORT         69.520000
# 29        Bern, Switzerland  UTILITIES        212.329280
# ..                      ...        ...               ...
# 168       Stockholm, Sweden    HOBBIES        117.280820
# 169       Stockholm, Sweden     MARKET        224.494110
# 170       Stockholm, Sweden       RENT        755.438683
# 171       Stockholm, Sweden     SALARY       2350.001232
# 172       Stockholm, Sweden  TRANSPORT         81.700000
# 173       Stockholm, Sweden  UTILITIES        102.579324
# 174      Stuttgart, Germany    HOBBIES        102.784400
# 175      Stuttgart, Germany     MARKET        175.160945
# 176      Stuttgart, Germany       RENT        645.000000
# 177      Stuttgart, Germany     SALARY       2368.275362
# 178      Stuttgart, Germany  TRANSPORT         80.000000
# 179      Stuttgart, Germany  UTILITIES        218.417018
# 180        Tallinn, Estonia    HOBBIES        102.133333
# 181        Tallinn, Estonia     MARKET        127.989582
# 182        Tallinn, Estonia       RENT        340.409836
# 183        Tallinn, Estonia     SALARY       1090.106780
# 184        Tallinn, Estonia  TRANSPORT         23.000000
# 185        Tallinn, Estonia  UTILITIES        212.097734
# 186         Vienna, Austria    HOBBIES         93.311475
# 187         Vienna, Austria     MARKET        227.973146
# 188         Vienna, Austria       RENT        640.588235
# 189         Vienna, Austria     SALARY       1872.645062
# 190         Vienna, Austria  TRANSPORT         40.000000
# 191         Vienna, Austria  UTILITIES        191.781969
# 192     Zurich, Switzerland    HOBBIES        199.660142
# 193     Zurich, Switzerland     MARKET        494.728792
# 194     Zurich, Switzerland       RENT       1179.451429
# 195     Zurich, Switzerland     SALARY       5205.386361
# 196     Zurich, Switzerland  TRANSPORT         74.800000
# 197     Zurich, Switzerland  UTILITIES        204.858411
#
# [198 rows x 3 columns]

# %%
# Total cost of living calculation
cashflow_ne_salary = data['item_type'] != 'SALARY'
total_cost_df = data[cashflow_ne_salary].groupby(['city_name']).sum() # SUMS ALL AVG_MONTHLY_PRICES FOR EACH NON-SALARY-ITEM
total_cost_df = total_cost_df.reset_index()
total_cost_df = total_cost_df.rename(columns={'avg_monthly_cost':'avg_total_cost_of_living'})
total_cost_df
# Out:
#                  city_name  avg_total_cost_of_living
# 0   Amsterdam, Netherlands               1784.537211
# 1         Barcelona, Spain               1237.191624
# 2       Basel, Switzerland               2077.771943
# 3          Berlin, Germany               1280.517418
# 4        Bern, Switzerland               1672.965013
# 5     Brno, Czech Republic                781.214388
# 6        Brussels, Belgium               1269.427998
# 7      Copenhagen, Denmark               1457.259099
# 8          Dublin, Ireland               1933.878086
# 9      Dusseldorf, Germany               1149.339210
# 10      Frankfurt, Germany               1352.503932
# 11     Geneva, Switzerland               2342.118977
# 12        Hamburg, Germany               1313.335169
# 13       Helsinki, Finland               1294.277192
# 14        Lisbon, Portugal               1001.220958
# 15     Ljubljana, Slovenia                915.363587
# 16  London, United Kingdom               2185.325634
# 17  Luxembourg, Luxembourg               1969.328275
# 18            Lyon, France               1157.741318
# 19           Madrid, Spain               1158.445196
# 20            Milan, Italy               1274.449308
# 21         Munich, Germany               1446.591028
# 22      Nuremberg, Germany               1111.765571
# 23            Oslo, Norway               1684.663328
# 24           Paris, France               1527.005283
# 25  Prague, Czech Republic                937.182969
# 26      Reykjavik, Iceland               1926.618533
# 27             Rome, Italy               1245.064551
# 28       Stockholm, Sweden               1281.492937
# 29      Stuttgart, Germany               1221.362364
# 30        Tallinn, Estonia                805.630486
# 31         Vienna, Austria               1193.654825
# 32     Zurich, Switzerland               2153.498774

# %%
# Variable data contains all our INTERESTING cost items.
data
# Out:
#                   city_name  item_type  avg_monthly_cost
# 0    Amsterdam, Netherlands    HOBBIES        127.158333
# 1    Amsterdam, Netherlands     MARKET        225.592814
# 2    Amsterdam, Netherlands       RENT       1143.055556
# 3    Amsterdam, Netherlands     SALARY       2492.607843
# 4    Amsterdam, Netherlands  TRANSPORT         93.000000
# 5    Amsterdam, Netherlands  UTILITIES        195.730508
# 6          Barcelona, Spain    HOBBIES        110.010714
# 7          Barcelona, Spain     MARKET        168.478419
# 8          Barcelona, Spain       RENT        726.666667
# 9          Barcelona, Spain     SALARY       1330.619032
# 10         Barcelona, Spain  TRANSPORT         50.000000
# 11         Barcelona, Spain  UTILITIES        182.035825
# 12       Basel, Switzerland    HOBBIES        214.328889
# 13       Basel, Switzerland     MARKET        507.185067
# 14       Basel, Switzerland       RENT       1012.000000
# 15       Basel, Switzerland     SALARY       4646.279906
# 16       Basel, Switzerland  TRANSPORT         70.400000
# 17       Basel, Switzerland  UTILITIES        273.857988
# 18          Berlin, Germany    HOBBIES         82.107692
# 19          Berlin, Germany     MARKET        188.188574
# 20          Berlin, Germany       RENT        653.871212
# 21          Berlin, Germany     SALARY       2157.578704
# 22          Berlin, Germany  TRANSPORT         81.000000
# 23          Berlin, Germany  UTILITIES        275.349939
# 24        Bern, Switzerland    HOBBIES        169.194667
# 25        Bern, Switzerland     MARKET        468.054400
# 26        Bern, Switzerland       RENT        753.866667
# 27        Bern, Switzerland     SALARY       4593.162282
# 28        Bern, Switzerland  TRANSPORT         69.520000
# 29        Bern, Switzerland  UTILITIES        212.329280
# ..                      ...        ...               ...
# 168       Stockholm, Sweden    HOBBIES        117.280820
# 169       Stockholm, Sweden     MARKET        224.494110
# 170       Stockholm, Sweden       RENT        755.438683
# 171       Stockholm, Sweden     SALARY       2350.001232
# 172       Stockholm, Sweden  TRANSPORT         81.700000
# 173       Stockholm, Sweden  UTILITIES        102.579324
# 174      Stuttgart, Germany    HOBBIES        102.784400
# 175      Stuttgart, Germany     MARKET        175.160945
# 176      Stuttgart, Germany       RENT        645.000000
# 177      Stuttgart, Germany     SALARY       2368.275362
# 178      Stuttgart, Germany  TRANSPORT         80.000000
# 179      Stuttgart, Germany  UTILITIES        218.417018
# 180        Tallinn, Estonia    HOBBIES        102.133333
# 181        Tallinn, Estonia     MARKET        127.989582
# 182        Tallinn, Estonia       RENT        340.409836
# 183        Tallinn, Estonia     SALARY       1090.106780
# 184        Tallinn, Estonia  TRANSPORT         23.000000
# 185        Tallinn, Estonia  UTILITIES        212.097734
# 186         Vienna, Austria    HOBBIES         93.311475
# 187         Vienna, Austria     MARKET        227.973146
# 188         Vienna, Austria       RENT        640.588235
# 189         Vienna, Austria     SALARY       1872.645062
# 190         Vienna, Austria  TRANSPORT         40.000000
# 191         Vienna, Austria  UTILITIES        191.781969
# 192     Zurich, Switzerland    HOBBIES        199.660142
# 193     Zurich, Switzerland     MARKET        494.728792
# 194     Zurich, Switzerland       RENT       1179.451429
# 195     Zurich, Switzerland     SALARY       5205.386361
# 196     Zurich, Switzerland  TRANSPORT         74.800000
# 197     Zurich, Switzerland  UTILITIES        204.858411
#
# [198 rows x 3 columns]

# %% [markdown]
# <h1>TODO:</h1><h5> 1) Create a new dataframe with (city, free_cash [salary - cost_of_living], salary avg_total_cost_of_living, avg_months_market, avg_months_transport, ..., avg_months_rent) </h5>
#     <h5> 2) Output final dataframe into a .csv file ready for tableau</h5>
