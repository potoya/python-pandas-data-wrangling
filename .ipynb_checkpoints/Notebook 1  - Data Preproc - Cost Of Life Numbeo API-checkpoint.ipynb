# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Just query with london.
url = 'https://www.numbeo.com/api/city_prices?api_key=b6vniprdzkppy7&query=London'
resp = requests.get(url)
print(resp.status_code)
# Out:
# 200

# %%
json = resp.json()
json
# Out:
# {'name': 'London, United Kingdom',
#  'currency': 'GBP',
#  'monthLastUpdate': 3,
#  'contributors': 728,
#  'yearLastUpdate': 2019,
#  'prices': [{'data_points': 98,
#    'item_id': 1,
#    'lowest_price': 10,
#    'average_price': 15,
#    'highest_price': 20,
#    'item_name': 'Meal, Inexpensive Restaurant, Restaurants'},
#   {'data_points': 90,
#    'item_id': 2,
#    'lowest_price': 40,
#    'average_price': 50,
#    'highest_price': 70,
#    'item_name': 'Meal for 2 People, Mid-range Restaurant, Three-course, Restaurants'},
#   {'data_points': 79,
#    'item_id': 3,
#    'lowest_price': 5,
#    'average_price': 6,
#    'highest_price': 7,
#    'item_name': 'McMeal at McDonalds (or Equivalent Combo Meal), Restaurants'},
#   {'data_points': 70,
#    'item_id': 4,
#    'lowest_price': 4,
#    'average_price': 5,
#    'highest_price': 5,
#    'item_name': 'Domestic Beer (0.5 liter draught), Restaurants'},
#   {'data_points': 65,
#    'item_id': 5,
#    'lowest_price': 4,
#    'average_price': 4.5,
#    'highest_price': 5,
#    'item_name': 'Imported Beer (0.33 liter bottle), Restaurants'},
#   {'data_points': 78,
#    'item_id': 6,
#    'lowest_price': 0.9,
#    'average_price': 1.3138461538461543,
#    'highest_price': 2,
#    'item_name': 'Coke/Pepsi (0.33 liter bottle), Restaurants'},
#   {'data_points': 84,
#    'item_id': 7,
#    'lowest_price': 0.6,
#    'average_price': 1.0026190476190477,
#    'highest_price': 1.5,
#    'item_name': 'Water (0.33 liter bottle) , Restaurants'},
#   {'data_points': 59,
#    'item_id': 8,
#    'lowest_price': 0.7,
#    'average_price': 0.9394896261585877,
#    'highest_price': 1.2,
#    'item_name': 'Milk (regular), (1 liter), Markets'},
#   {'data_points': 48,
#    'item_id': 9,
#    'lowest_price': 0.7,
#    'average_price': 1.0873398189775918,
#    'highest_price': 1.5,
#    'item_name': 'Loaf of Fresh White Bread (500g), Markets'},
#   {'data_points': 50,
#    'item_id': 11,
#    'lowest_price': 1.3,
#    'average_price': 2.0446,
#    'highest_price': 3.3,
#    'item_name': 'Eggs (regular) (12), Markets'},
#   {'data_points': 26,
#    'item_id': 12,
#    'lowest_price': 5,
#    'average_price': 6.6097914680552305,
#    'highest_price': 10,
#    'item_name': 'Local Cheese (1kg), Markets'},
#   {'data_points': 32,
#    'item_id': 13,
#    'lowest_price': 0.5,
#    'average_price': 0.9249999999999999,
#    'highest_price': 1.4,
#    'item_name': 'Water (1.5 liter bottle), Markets'},
#   {'data_points': 39,
#    'item_id': 14,
#    'lowest_price': 7,
#    'average_price': 8,
#    'highest_price': 10,
#    'item_name': 'Bottle of Wine (Mid-Range), Markets'},
#   {'data_points': 23,
#    'item_id': 15,
#    'lowest_price': 1,
#    'average_price': 1.5522779280216352,
#    'highest_price': 2,
#    'item_name': 'Domestic Beer (0.5 liter bottle), Markets'},
#   {'data_points': 21,
#    'item_id': 16,
#    'lowest_price': 1.2,
#    'average_price': 2.0666666666666664,
#    'highest_price': 3,
#    'item_name': 'Imported Beer (0.33 liter bottle), Markets'},
#   {'data_points': 32,
#    'item_id': 17,
#    'lowest_price': 10,
#    'average_price': 11,
#    'highest_price': 12.3,
#    'item_name': 'Cigarettes 20 Pack (Marlboro), Markets'},
#   {'data_points': 87,
#    'item_id': 18,
#    'lowest_price': 1.7,
#    'average_price': 2.5,
#    'highest_price': 3.3,
#    'item_name': 'One-way Ticket (Local Transport), Transportation'},
#   {'data_points': 36,
#    'item_id': 19,
#    'lowest_price': 5,
#    'average_price': 6.29,
#    'highest_price': 9,
#    'item_name': 'Chicken Breasts (Boneless, Skinless), (1kg), Markets'},
#   {'data_points': 85,
#    'item_id': 20,
#    'lowest_price': 130,
#    'average_price': 150,
#    'highest_price': 190,
#    'item_name': 'Monthly Pass (Regular Price), Transportation'},
#   {'data_points': 65,
#    'item_id': 24,
#    'lowest_price': 1.2,
#    'average_price': 1.2967538461538444,
#    'highest_price': 1.38,
#    'item_name': 'Gasoline (1 liter), Transportation'},
#   {'data_points': 21,
#    'item_id': 25,
#    'lowest_price': 16000,
#    'average_price': 19000,
#    'highest_price': 21000,
#    'item_name': 'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car), Transportation'},
#   {'data_points': 93,
#    'item_id': 26,
#    'lowest_price': 1400,
#    'average_price': 1742.741935483871,
#    'highest_price': 2200,
#    'item_name': 'Apartment (1 bedroom) in City Centre, Rent Per Month'},
#   {'data_points': 86,
#    'item_id': 27,
#    'lowest_price': 1000,
#    'average_price': 1233.7209302325582,
#    'highest_price': 1500,
#    'item_name': 'Apartment (1 bedroom) Outside of Centre, Rent Per Month'},
#   {'data_points': 65,
#    'item_id': 28,
#    'lowest_price': 2500,
#    'average_price': 3303.4615384615386,
#    'highest_price': 5000,
#    'item_name': 'Apartment (3 bedrooms) in City Centre, Rent Per Month'},
#   {'data_points': 80,
#    'item_id': 29,
#    'lowest_price': 1600,
#    'average_price': 1992.3625,
#    'highest_price': 2500,
#    'item_name': 'Apartment (3 bedrooms) Outside of Centre, Rent Per Month'},
#   {'data_points': 80,
#    'item_id': 30,
#    'lowest_price': 90,
#    'average_price': 158.29063637090115,
#    'highest_price': 255,
#    'item_name': 'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment, Utilities (Monthly)'},
#   {'data_points': 32,
#    'item_id': 32,
#    'lowest_price': 0.03,
#    'average_price': 0.11718750000000003,
#    'highest_price': 0.3,
#    'item_name': '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans), Utilities (Monthly)'},
#   {'data_points': 102,
#    'item_id': 33,
#    'lowest_price': 25,
#    'average_price': 32.20558823529411,
#    'highest_price': 45,
#    'item_name': 'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL), Utilities (Monthly)'},
#   {'data_points': 87,
#    'item_id': 40,
#    'lowest_price': 25,
#    'average_price': 45.68314724137931,
#    'highest_price': 80,
#    'item_name': 'Fitness Club, Monthly Fee for 1 Adult, Sports And Leisure'},
#   {'data_points': 37,
#    'item_id': 42,
#    'lowest_price': 5,
#    'average_price': 10.486486486486486,
#    'highest_price': 15,
#    'item_name': 'Tennis Court Rent (1 Hour on Weekend), Sports And Leisure'},
#   {'data_points': 86,
#    'item_id': 44,
#    'lowest_price': 10,
#    'average_price': 12.25,
#    'highest_price': 15,
#    'item_name': 'Cinema, International Release, 1 Seat, Sports And Leisure'},
#   {'data_points': 80,
#    'item_id': 60,
#    'lowest_price': 40,
#    'average_price': 65.024875,
#    'highest_price': 80,
#    'item_name': '1 Pair of Jeans (Levis 501 Or Similar), Clothing And Shoes'},
#   {'data_points': 79,
#    'item_id': 62,
#    'lowest_price': 20,
#    'average_price': 30.670759493670882,
#    'highest_price': 45,
#    'item_name': '1 Summer Dress in a Chain Store (Zara, H&M, ...), Clothing And Shoes'},
#   {'data_points': 95,
#    'item_id': 64,
#    'lowest_price': 50,
#    'average_price': 68.25263157894737,
#    'highest_price': 90,
#    'item_name': '1 Pair of Nike Running Shoes (Mid-Range), Clothing And Shoes'},
#   {'data_points': 80,
#    'item_id': 66,
#    'lowest_price': 50,
#    'average_price': 79,
#    'highest_price': 120,
#    'item_name': '1 Pair of Men Leather Business Shoes, Clothing And Shoes'},
#   {'data_points': 24,
#    'item_id': 206,
#    'lowest_price': 17000,
#    'average_price': 20794.75,
#    'highest_price': 25000,
#    'item_name': 'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car), Transportation'},
#   {'data_points': 34,
#    'item_id': 224,
#    'lowest_price': 800,
#    'average_price': 1282.3352941176472,
#    'highest_price': 1600,
#    'item_name': 'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child, Childcare'},
#   {'data_points': 20,
#    'item_id': 100,
#    'lowest_price': 9200,
#    'average_price': 13270.488802088716,
#    'highest_price': 16246,
#    'item_name': 'Price per Square Meter to Buy Apartment in City Centre, Buy Apartment Price'},
#   {'data_points': 27,
#    'item_id': 228,
#    'lowest_price': 10000,
#    'average_price': 16936.962962962964,
#    'highest_price': 23000,
#    'item_name': 'International Primary School, Yearly for 1 Child, Childcare'},
#   {'data_points': 20,
#    'item_id': 101,
#    'lowest_price': 4305.564166683888,
#    'average_price': 7332.75,
#    'highest_price': 10000,
#    'item_name': 'Price per Square Meter to Buy Apartment Outside of Centre, Buy Apartment Price'},
#   {'data_points': 78,
#    'item_id': 105,
#    'lowest_price': 1274,
#    'average_price': 1975.5031389444268,
#    'highest_price': 3200,
#    'item_name': 'Average Monthly Net Salary (After Tax), Salaries And Financing'},
#   {'data_points': 44,
#    'item_id': 106,
#    'lowest_price': 2,
#    'average_price': 3.151818181818182,
#    'highest_price': 4.17,
#    'item_name': 'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate, Salaries And Financing'},
#   {'data_points': 60,
#    'item_id': 107,
#    'lowest_price': 3,
#    'average_price': 5,
#    'highest_price': 5,
#    'item_name': 'Taxi Start (Normal Tariff), Transportation'},
#   {'data_points': 21,
#    'item_id': 108,
#    'lowest_price': 1.71,
#    'average_price': 3,
#    'highest_price': 4,
#    'item_name': 'Taxi 1km (Normal Tariff), Transportation'},
#   {'data_points': 23,
#    'item_id': 109,
#    'lowest_price': 28.57,
#    'average_price': 40,
#    'highest_price': 60,
#    'item_name': 'Taxi 1hour Waiting (Normal Tariff), Transportation'},
#   {'data_points': 24,
#    'item_id': 110,
#    'lowest_price': 1.3,
#    'average_price': 2.1441666666666666,
#    'highest_price': 3.6,
#    'item_name': 'Apples (1kg), Markets'},
#   {'data_points': 23,
#    'item_id': 111,
#    'lowest_price': 1.3,
#    'average_price': 2.067391304347826,
#    'highest_price': 3,
#    'item_name': 'Oranges (1kg), Markets'},
#   {'data_points': 27,
#    'item_id': 112,
#    'lowest_price': 0.8,
#    'average_price': 1.1262962962962964,
#    'highest_price': 2,
#    'item_name': 'Potato (1kg), Markets'},
#   {'data_points': 26,
#    'item_id': 113,
#    'lowest_price': 0.5,
#    'average_price': 0.8142307692307693,
#    'highest_price': 1,
#    'item_name': 'Lettuce (1 head), Markets'},
#   {'data_points': 92,
#    'item_id': 114,
#    'lowest_price': 2.4,
#    'average_price': 2.742282608695653,
#    'highest_price': 3.3,
#    'item_name': 'Cappuccino (regular), Restaurants'},
#   {'data_points': 33,
#    'item_id': 115,
#    'lowest_price': 1,
#    'average_price': 1.4633333333333334,
#    'highest_price': 2.99,
#    'item_name': 'Rice (white), (1kg), Markets'},
#   {'data_points': 20,
#    'item_id': 116,
#    'lowest_price': 1.6,
#    'average_price': 2.2432542442016823,
#    'highest_price': 4,
#    'item_name': 'Tomato (1kg), Markets'},
#   {'data_points': 23,
#    'item_id': 118,
#    'lowest_price': 0.75,
#    'average_price': 1.1517391304347826,
#    'highest_price': 2,
#    'item_name': 'Banana (1kg), Markets'},
#   {'data_points': 25,
#    'item_id': 119,
#    'lowest_price': 0.7,
#    'average_price': 1.0588,
#    'highest_price': 2,
#    'item_name': 'Onion (1kg), Markets'},
#   {'data_points': 21,
#    'item_id': 121,
#    'lowest_price': 5,
#    'average_price': 8.94691365826693,
#    'highest_price': 15,
#    'item_name': 'Beef Round (1kg) (or Equivalent Back Leg Red Meat), Markets'}],
#  'city_id': 6512}

# %%
df = json_normalize(json)
df.head()
# Out:
#    city_id  contributors currency  monthLastUpdate                    name  \
# 0     6512           728      GBP                3  London, United Kingdom
#
#                                               prices  yearLastUpdate
# 0  [{'data_points': 98, 'item_id': 1, 'lowest_pri...            2019

# %%
prices_df = json_normalize(json['prices'])
prices_df.head()
# Out:
#    average_price  data_points  highest_price  item_id  \
# 0           15.0           98           20.0        1
# 1           50.0           90           70.0        2
# 2            6.0           79            7.0        3
# 3            5.0           70            5.0        4
# 4            4.5           65            5.0        5
#
#                                            item_name  lowest_price
# 0          Meal, Inexpensive Restaurant, Restaurants          10.0
# 1  Meal for 2 People, Mid-range Restaurant, Three...          40.0
# 2  McMeal at McDonalds (or Equivalent Combo Meal)...           5.0
# 3     Domestic Beer (0.5 liter draught), Restaurants           4.0
# 4     Imported Beer (0.33 liter bottle), Restaurants           4.0

# %%
new_df = prices_df
new_df['city_name'] = df['name'].values[0]
new_df['currency'] = df['currency'].values[0]
new_df['contributors'] = df['contributors'].values[0]
new_df['city_id'] = df['city_id'].values[0]
new_df['lastUpdated'] = str(df['monthLastUpdate'].values[0]) + '/' + str(df['yearLastUpdate'].values[0])

# %%
reorder_attrs = ['city_id','city_name', 'item_id', 'item_name', 
 'lowest_price', 'highest_price', 'average_price', 
 'currency', 'contributors','data_points']
new_df = new_df[reorder_attrs]

# %%
# Make a function out of this cleaning to apply per each city.
def jsonCityPricesToDF(json):
    df = json_normalize(json)
    prices_df = json_normalize(json['prices'])
    new_df = prices_df
    new_df['city_name'] = df['name'].values[0]
    new_df['currency'] = df['currency'].values[0]
    new_df['contributors'] = df['contributors'].values[0]
    new_df['city_id'] = df['city_id'].values[0]
    new_df['lastUpdated'] = str(df['monthLastUpdate'].values[0]) + '/' + str(df['yearLastUpdate'].values[0])
    reorder_attrs = ['city_id','city_name', 'item_id', 'item_name', 'lowest_price', 'highest_price', 'average_price', 'currency', 'contributors','data_points']
    return new_df[reorder_attrs]

def getPrices(city):
    url = 'https://www.numbeo.com/api/city_prices?api_key=b6vniprdzkppy7&query={}'.format(city)
    resp = requests.get(url)
    if resp.status_code != 200:
        raise Exception(resp.status_code)
    else:
        return resp.json()

# %%
# Load cities of interest
citiesOfInterest = pd.read_csv('DataVisual_Cities.csv', sep=';')
citiesOfInterest['to EUR'] = citiesOfInterest['to EUR'].str.replace(',','.')
citiesOfInterest.head()
# Out:
#    Cantidad  CITY_NAME   Unnamed: 2  GLOBAL  EUROPE  BUSINESS INSIDER  \
# 0         1     Zurich  Switzerland       1       1               2.0
# 1         2     Geneva  Switzerland       1       1               6.0
# 2         3      Basel  Switzerland       1       1               8.0
# 3         4       Bern  Switzerland       1       1              11.0
# 4         5  Amsterdam   Netherland       2       2               9.0
#
#   Currency to EUR Population
# 0      CHF   0.88   402.762
# 1      CHF   0.88   198.979
# 2      CHF   0.88   171.017
# 3      CHF   0.88   133.115
# 4      EUR      1   821.752

# %%
# Query price items for all cities of interest.
i = 0
for city in citiesOfInterest['CITY_NAME']:
    json = getPrices(city)
    cityPricesDF = jsonCityPricesToDF(json)
    cityPricesDF['toEur'] = citiesOfInterest['to EUR'].values[i]
    cityPricesDF.toEur.apply(lambda x: float(x))
    if i == 0:
        df = cityPricesDF
    else:
        df = pd.concat([df, cityPricesDF], sort=False)
    i+=1

# %%
df.city_name.value_counts()
# Out:
# Madrid, Spain             55
# Paris, France             55
# Oslo, Norway              55
# Tallinn, Estonia          55
# Helsinki, Finland         55
# Ljubljana, Slovenia       55
# Stuttgart, Germany        55
# Brno, Czech Republic      55
# Amsterdam, Netherlands    55
# Barcelona, Spain          55
# Dublin, Ireland           55
# Zurich, Switzerland       55
# Stockholm, Sweden         55
# Brussels, Belgium         55
# Berlin, Germany           55
# Geneva, Switzerland       55
# Basel, Switzerland        55
# Dusseldorf, Germany       55
# Reykjavik, Iceland        55
# Bern, Switzerland         55
# Lyon, France              55
# Rome, Italy               55
# Luxembourg, Luxembourg    55
# Milan, Italy              55
# Copenhagen, Denmark       55
# Lisbon, Portugal          55
# Nuremberg, Germany        55
# Vienna, Austria           55
# Frankfurt, Germany        55
# Munich, Germany           55
# Prague, Czech Republic    55
# London, United Kingdom    55
# Hamburg, Germany          55
# Name: city_name, dtype: int64

# %%
len(df.city_name.value_counts())
# Out:
# 33

# %%
df.to_csv('EU-Popular-Cities-Prices - PreProcesed.csv', sep=',')
